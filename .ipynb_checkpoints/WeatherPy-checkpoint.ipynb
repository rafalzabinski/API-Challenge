# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Description of three observable trends based on the data:
# 1. Cities closer to equator are warmer.
# 2. Humidity dosen't seem to be afected by the latitude. At least not in march.
# 3. The is no stron corelation between latitude and wind speed or cloudiness.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import date


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
print(weather_api_key)
# Out:
# f05b91b3ef344d0ceff8bce33505e03e

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url= "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

counter = 0
city_name =[]
cloudiness =[]
country =[]
date =[]
humidity = []
lat = []
lng = []
max_temp =[]
wind_speed =[]

# %%
print("Beginning Data Retrieval")
print("------------------------")


for city in cities:
    try:
        counter = counter + 1
        print(f"Processing Record {counter} of Set 1 | {city}")
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
    except (KeyError, IndexError):
        print("Whoops. City not found! But I will keep processing!")     
print(f"All done! I managed to get data on {counter} cities")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | rusape
# Processing Record 5 of Set 1 | kaeo
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | katangli
# Processing Record 8 of Set 1 | duldurga
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | meulaboh
# Processing Record 11 of Set 1 | sinnamary
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | tura
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | lata
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | debre tabor
# Processing Record 18 of Set 1 | niagara falls
# Processing Record 19 of Set 1 | taolanaro
# Whoops. City not found! But I will keep processing!
# Processing Record 20 of Set 1 | abnub
# Processing Record 21 of Set 1 | andros town
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | san cristobal
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | morristown
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | gigmoto
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | sobolevo
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | port shepstone
# Processing Record 35 of Set 1 | mezen
# Processing Record 36 of Set 1 | santa isabel do rio negro
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | olinda
# Processing Record 41 of Set 1 | afmadu
# Whoops. City not found! But I will keep processing!
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | baykit
# Processing Record 46 of Set 1 | gorontalo
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | lillesand
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 51 of Set 1 | solnechnyy
# Processing Record 52 of Set 1 | novobirilyussy
# Processing Record 53 of Set 1 | constitucion
# Processing Record 54 of Set 1 | esmeraldas
# Processing Record 55 of Set 1 | gobabis
# Processing Record 56 of Set 1 | marau
# Processing Record 57 of Set 1 | jamestown
# Processing Record 58 of Set 1 | mys shmidta
# Whoops. City not found! But I will keep processing!
# Processing Record 59 of Set 1 | jalingo
# Processing Record 60 of Set 1 | hirara
# Processing Record 61 of Set 1 | palmer
# Processing Record 62 of Set 1 | cockburn town
# Processing Record 63 of Set 1 | georgetown
# Processing Record 64 of Set 1 | puerto ayora
# Processing Record 65 of Set 1 | chuy
# Processing Record 66 of Set 1 | belmonte
# Processing Record 67 of Set 1 | cherskiy
# Processing Record 68 of Set 1 | henties bay
# Processing Record 69 of Set 1 | langres
# Processing Record 70 of Set 1 | busselton
# Processing Record 71 of Set 1 | tyrma
# Processing Record 72 of Set 1 | san quintin
# Processing Record 73 of Set 1 | jijiga
# Processing Record 74 of Set 1 | port alfred
# Processing Record 75 of Set 1 | rolim de moura
# Whoops. City not found! But I will keep processing!
# Processing Record 76 of Set 1 | tasiilaq
# Processing Record 77 of Set 1 | tuktoyaktuk
# Processing Record 78 of Set 1 | mehamn
# Processing Record 79 of Set 1 | tiksi
# Processing Record 80 of Set 1 | carnarvon
# Processing Record 81 of Set 1 | buraydah
# Processing Record 82 of Set 1 | chokurdakh
# Processing Record 83 of Set 1 | uwayl
# Whoops. City not found! But I will keep processing!
# Processing Record 84 of Set 1 | moerai
# Processing Record 85 of Set 1 | maniitsoq
# Processing Record 86 of Set 1 | saint-philippe
# Processing Record 87 of Set 1 | cruzeiro do sul
# Processing Record 88 of Set 1 | bismarck
# Processing Record 89 of Set 1 | sao felix do xingu
# Processing Record 90 of Set 1 | dunedin
# Processing Record 91 of Set 1 | hobart
# Processing Record 92 of Set 1 | bredasdorp
# Processing Record 93 of Set 1 | garango
# Processing Record 94 of Set 1 | amderma
# Whoops. City not found! But I will keep processing!
# Processing Record 95 of Set 1 | ivanteyevka
# Processing Record 96 of Set 1 | mitu
# Processing Record 97 of Set 1 | souflion
# Whoops. City not found! But I will keep processing!
# Processing Record 98 of Set 1 | vila franca do campo
# Processing Record 99 of Set 1 | zhigansk
# Processing Record 100 of Set 1 | banjarmasin
# Processing Record 101 of Set 1 | mvuma
# Processing Record 102 of Set 1 | belushya guba
# Whoops. City not found! But I will keep processing!
# Processing Record 103 of Set 1 | verkhnyaya inta
# Processing Record 104 of Set 1 | bechem
# Processing Record 105 of Set 1 | east london
# Processing Record 106 of Set 1 | saskylakh
# Processing Record 107 of Set 1 | bobonong
# Whoops. City not found! But I will keep processing!
# Processing Record 108 of Set 1 | kasane
# Processing Record 109 of Set 1 | nizip
# Processing Record 110 of Set 1 | xenia
# Processing Record 111 of Set 1 | bethel
# Processing Record 112 of Set 1 | berlevag
# Processing Record 113 of Set 1 | avarua
# Processing Record 114 of Set 1 | ormara
# Processing Record 115 of Set 1 | airai
# Processing Record 116 of Set 1 | port elizabeth
# Processing Record 117 of Set 1 | yulara
# Processing Record 118 of Set 1 | rawson
# Processing Record 119 of Set 1 | dudinka
# Processing Record 120 of Set 1 | mangai
# Processing Record 121 of Set 1 | mar del plata
# Processing Record 122 of Set 1 | kapaa
# Processing Record 123 of Set 1 | illoqqortoormiut
# Whoops. City not found! But I will keep processing!
# Processing Record 124 of Set 1 | albany
# Processing Record 125 of Set 1 | pangnirtung
# Processing Record 126 of Set 1 | attawapiskat
# Whoops. City not found! But I will keep processing!
# Processing Record 127 of Set 1 | ahuimanu
# Processing Record 128 of Set 1 | xuddur
# Processing Record 129 of Set 1 | nizhneyansk
# Whoops. City not found! But I will keep processing!
# Processing Record 130 of Set 1 | mokrousovo
# Processing Record 131 of Set 1 | erzin
# Processing Record 132 of Set 1 | babati
# Processing Record 133 of Set 1 | ponta do sol
# Processing Record 134 of Set 1 | klaksvik
# Processing Record 135 of Set 1 | dickinson
# Processing Record 136 of Set 1 | bathsheba
# Processing Record 137 of Set 1 | manerbio
# Processing Record 138 of Set 1 | rungata
# Whoops. City not found! But I will keep processing!
# Processing Record 139 of Set 1 | hermanus
# Processing Record 140 of Set 1 | bambanglipuro
# Processing Record 141 of Set 1 | inirida
# Processing Record 142 of Set 1 | amahai
# Processing Record 143 of Set 1 | qaanaaq
# Processing Record 144 of Set 1 | la grande
# Processing Record 145 of Set 1 | codrington
# Processing Record 146 of Set 1 | puerto baquerizo moreno
# Processing Record 147 of Set 1 | nishihara
# Processing Record 148 of Set 1 | shahrud
# Processing Record 149 of Set 1 | bantry
# Processing Record 150 of Set 1 | arraial do cabo
# Processing Record 151 of Set 1 | kangaatsiaq
# Processing Record 152 of Set 1 | hilo
# Processing Record 153 of Set 1 | hermitage
# Processing Record 154 of Set 1 | ust-kamchatsk
# Whoops. City not found! But I will keep processing!
# Processing Record 155 of Set 1 | praia da vitoria
# Processing Record 156 of Set 1 | bathurst
# Processing Record 157 of Set 1 | dezful
# Processing Record 158 of Set 1 | kosh-agach
# Processing Record 159 of Set 1 | sar-e pul
# Processing Record 160 of Set 1 | mamlyutka
# Processing Record 161 of Set 1 | la ronge
# Processing Record 162 of Set 1 | fairbanks
# Processing Record 163 of Set 1 | guanhaes
# Processing Record 164 of Set 1 | acapulco
# Processing Record 165 of Set 1 | barentsburg
# Whoops. City not found! But I will keep processing!
# Processing Record 166 of Set 1 | malakal
# Processing Record 167 of Set 1 | ponta delgada
# Processing Record 168 of Set 1 | iqaluit
# Processing Record 169 of Set 1 | karkaralinsk
# Whoops. City not found! But I will keep processing!
# Processing Record 170 of Set 1 | burica
# Whoops. City not found! But I will keep processing!
# Processing Record 171 of Set 1 | akyab
# Processing Record 172 of Set 1 | bonavista
# Processing Record 173 of Set 1 | san rafael
# Processing Record 174 of Set 1 | tazovskiy
# Processing Record 175 of Set 1 | ancud
# Processing Record 176 of Set 1 | awjilah
# Processing Record 177 of Set 1 | aklavik
# Processing Record 178 of Set 1 | easton
# Processing Record 179 of Set 1 | caravelas
# Processing Record 180 of Set 1 | kruisfontein
# Processing Record 181 of Set 1 | kasamwa
# Processing Record 182 of Set 1 | calamar
# Processing Record 183 of Set 1 | svetlaya
# Processing Record 184 of Set 1 | sorkjosen
# Processing Record 185 of Set 1 | fredericton
# Processing Record 186 of Set 1 | longyearbyen
# Processing Record 187 of Set 1 | husavik
# Processing Record 188 of Set 1 | mahebourg
# Processing Record 189 of Set 1 | cam ranh
# Processing Record 190 of Set 1 | yichang
# Processing Record 191 of Set 1 | mitsamiouli
# Processing Record 192 of Set 1 | vrangel
# Processing Record 193 of Set 1 | yanchukan
# Whoops. City not found! But I will keep processing!
# Processing Record 194 of Set 1 | ust-maya
# Processing Record 195 of Set 1 | cape town
# Processing Record 196 of Set 1 | axim
# Processing Record 197 of Set 1 | ji-parana
# Whoops. City not found! But I will keep processing!
# Processing Record 198 of Set 1 | vastervik
# Whoops. City not found! But I will keep processing!
# Processing Record 199 of Set 1 | wuwei
# Processing Record 200 of Set 1 | karakol
# Processing Record 201 of Set 1 | hobyo
# Processing Record 202 of Set 1 | san patricio
# Processing Record 203 of Set 1 | blagodatnoye
# Processing Record 204 of Set 1 | alihe
# Processing Record 205 of Set 1 | nanortalik
# Processing Record 206 of Set 1 | keetmanshoop
# Processing Record 207 of Set 1 | hasaki
# Processing Record 208 of Set 1 | turayf
# Processing Record 209 of Set 1 | aanekoski
# Processing Record 210 of Set 1 | spas-demensk
# Processing Record 211 of Set 1 | brza palanka
# Processing Record 212 of Set 1 | mendahara
# Whoops. City not found! But I will keep processing!
# Processing Record 213 of Set 1 | dikson
# Processing Record 214 of Set 1 | mantua
# Processing Record 215 of Set 1 | lagunas
# Processing Record 216 of Set 1 | pisco
# Processing Record 217 of Set 1 | herat
# Processing Record 218 of Set 1 | norman wells
# Processing Record 219 of Set 1 | saldanha
# Processing Record 220 of Set 1 | atherton
# Processing Record 221 of Set 1 | half moon bay
# Processing Record 222 of Set 1 | jyvaskyla
# Processing Record 223 of Set 1 | clearlake
# Processing Record 224 of Set 1 | cockburn harbour
# Whoops. City not found! But I will keep processing!
# Processing Record 225 of Set 1 | beringovskiy
# Processing Record 226 of Set 1 | wattegama
# Processing Record 227 of Set 1 | ouargaye
# Processing Record 228 of Set 1 | kavieng
# Processing Record 229 of Set 1 | labuhan
# Processing Record 230 of Set 1 | komsomolskiy
# Processing Record 231 of Set 1 | katsuura
# Processing Record 232 of Set 1 | deogarh
# Processing Record 233 of Set 1 | aykhal
# Processing Record 234 of Set 1 | el alto
# Processing Record 235 of Set 1 | derzhavinsk
# Processing Record 236 of Set 1 | guerrero negro
# Processing Record 237 of Set 1 | kalianget
# Processing Record 238 of Set 1 | hithadhoo
# Processing Record 239 of Set 1 | puerto colombia
# Processing Record 240 of Set 1 | udachnyy
# Processing Record 241 of Set 1 | srednekolymsk
# Processing Record 242 of Set 1 | karamea
# Whoops. City not found! But I will keep processing!
# Processing Record 243 of Set 1 | kodiak
# Processing Record 244 of Set 1 | takoradi
# Processing Record 245 of Set 1 | sept-iles
# Processing Record 246 of Set 1 | omboue
# Processing Record 247 of Set 1 | mecca
# Processing Record 248 of Set 1 | honningsvag
# Processing Record 249 of Set 1 | brits
# Processing Record 250 of Set 1 | tsihombe
# Whoops. City not found! But I will keep processing!
# Processing Record 251 of Set 1 | genhe
# Processing Record 252 of Set 1 | saint george
# Processing Record 253 of Set 1 | ilulissat
# Processing Record 254 of Set 1 | padang
# Processing Record 255 of Set 1 | makakilo city
# Processing Record 256 of Set 1 | grand gaube
# Processing Record 257 of Set 1 | namatanai
# Processing Record 258 of Set 1 | coihaique
# Processing Record 259 of Set 1 | hami
# Processing Record 260 of Set 1 | fortuna
# Processing Record 261 of Set 1 | pontal do parana
# Processing Record 262 of Set 1 | liling
# Processing Record 263 of Set 1 | saint anthony
# Processing Record 264 of Set 1 | port-cartier
# Processing Record 265 of Set 1 | saint marys
# Processing Record 266 of Set 1 | sur
# Processing Record 267 of Set 1 | pacific grove
# Processing Record 268 of Set 1 | san jeronimo
# Processing Record 269 of Set 1 | bagdarin
# Processing Record 270 of Set 1 | srivardhan
# Processing Record 271 of Set 1 | berbera
# Processing Record 272 of Set 1 | taoudenni
# Processing Record 273 of Set 1 | klyuchi
# Processing Record 274 of Set 1 | malanje
# Processing Record 275 of Set 1 | mombetsu
# Processing Record 276 of Set 1 | ribeira grande
# Processing Record 277 of Set 1 | alta floresta
# Processing Record 278 of Set 1 | crixas
# Processing Record 279 of Set 1 | maningrida
# Processing Record 280 of Set 1 | porto novo
# Processing Record 281 of Set 1 | thibodaux
# Processing Record 282 of Set 1 | lac du bonnet
# Processing Record 283 of Set 1 | faanui
# Processing Record 284 of Set 1 | tsuruoka
# Processing Record 285 of Set 1 | ostrovnoy
# Processing Record 286 of Set 1 | kargasok
# Processing Record 287 of Set 1 | hargeysa
# Processing Record 288 of Set 1 | harrisonburg
# Processing Record 289 of Set 1 | wenling
# Processing Record 290 of Set 1 | narva-joesuu
# Processing Record 291 of Set 1 | trelew
# Processing Record 292 of Set 1 | kununurra
# Processing Record 293 of Set 1 | umm lajj
# Processing Record 294 of Set 1 | nuuk
# Processing Record 295 of Set 1 | clyde river
# Processing Record 296 of Set 1 | caucaia
# Processing Record 297 of Set 1 | coquimbo
# Processing Record 298 of Set 1 | lingion
# Processing Record 299 of Set 1 | lagoa
# Processing Record 300 of Set 1 | mentok
# Whoops. City not found! But I will keep processing!
# Processing Record 301 of Set 1 | lavrentiya
# Processing Record 302 of Set 1 | vestmannaeyjar
# Processing Record 303 of Set 1 | bambous virieux
# Processing Record 304 of Set 1 | victoria
# Processing Record 305 of Set 1 | nguiu
# Whoops. City not found! But I will keep processing!
# Processing Record 306 of Set 1 | grand river south east
# Whoops. City not found! But I will keep processing!
# Processing Record 307 of Set 1 | korla
# Processing Record 308 of Set 1 | aksarka
# Processing Record 309 of Set 1 | belaya gora
# Processing Record 310 of Set 1 | arlit
# Processing Record 311 of Set 1 | atasu
# Processing Record 312 of Set 1 | kahului
# Processing Record 313 of Set 1 | vallenar
# Processing Record 314 of Set 1 | kasaragod
# Processing Record 315 of Set 1 | beyneu
# Processing Record 316 of Set 1 | beloha
# Processing Record 317 of Set 1 | bria
# Processing Record 318 of Set 1 | barbar
# Whoops. City not found! But I will keep processing!
# Processing Record 319 of Set 1 | novyy urengoy
# Processing Record 320 of Set 1 | muros
# Processing Record 321 of Set 1 | cumpas
# Processing Record 322 of Set 1 | higuey
# Whoops. City not found! But I will keep processing!
# Processing Record 323 of Set 1 | tomatlan
# Processing Record 324 of Set 1 | wanderlandia
# Whoops. City not found! But I will keep processing!
# Processing Record 325 of Set 1 | stoyba
# Whoops. City not found! But I will keep processing!
# Processing Record 326 of Set 1 | zhangye
# Processing Record 327 of Set 1 | igdir
# Processing Record 328 of Set 1 | sitka
# Processing Record 329 of Set 1 | seydi
# Processing Record 330 of Set 1 | nome
# Processing Record 331 of Set 1 | marsh harbour
# Processing Record 332 of Set 1 | khor
# Processing Record 333 of Set 1 | vieux-habitants
# Processing Record 334 of Set 1 | bela vista
# Processing Record 335 of Set 1 | poquoson
# Processing Record 336 of Set 1 | havoysund
# Processing Record 337 of Set 1 | shaturtorf
# Processing Record 338 of Set 1 | margate
# Processing Record 339 of Set 1 | paciran
# Processing Record 340 of Set 1 | hay river
# Processing Record 341 of Set 1 | urdzhar
# Whoops. City not found! But I will keep processing!
# Processing Record 342 of Set 1 | agadez
# Processing Record 343 of Set 1 | meyungs
# Whoops. City not found! But I will keep processing!
# Processing Record 344 of Set 1 | taksimo
# Processing Record 345 of Set 1 | yaan
# Processing Record 346 of Set 1 | noumea
# Processing Record 347 of Set 1 | grindavik
# Processing Record 348 of Set 1 | lodwar
# Processing Record 349 of Set 1 | itaquyry
# Processing Record 350 of Set 1 | malindi
# Processing Record 351 of Set 1 | cabo san lucas
# Processing Record 352 of Set 1 | kamenka
# Processing Record 353 of Set 1 | ferry pass
# Processing Record 354 of Set 1 | alofi
# Processing Record 355 of Set 1 | antofagasta
# Processing Record 356 of Set 1 | rocha
# Processing Record 357 of Set 1 | tual
# Processing Record 358 of Set 1 | tanjong sepat
# Whoops. City not found! But I will keep processing!
# Processing Record 359 of Set 1 | samusu
# Whoops. City not found! But I will keep processing!
# Processing Record 360 of Set 1 | camacha
# Processing Record 361 of Set 1 | zarubino
# Processing Record 362 of Set 1 | pevek
# Processing Record 363 of Set 1 | bereda
# Processing Record 364 of Set 1 | las lomas
# Processing Record 365 of Set 1 | vohma
# Processing Record 366 of Set 1 | hokitika
# Processing Record 367 of Set 1 | greenfield
# Processing Record 368 of Set 1 | leningradskiy
# Processing Record 369 of Set 1 | damphu
# Processing Record 370 of Set 1 | port lincoln
# Processing Record 371 of Set 1 | moroto
# Processing Record 372 of Set 1 | portoferraio
# Processing Record 373 of Set 1 | necochea
# Processing Record 374 of Set 1 | cayenne
# Processing Record 375 of Set 1 | augusto correa
# Processing Record 376 of Set 1 | aswan
# Processing Record 377 of Set 1 | talca
# Processing Record 378 of Set 1 | piterka
# Processing Record 379 of Set 1 | nuevitas
# Processing Record 380 of Set 1 | kulhudhuffushi
# Processing Record 381 of Set 1 | riyadh
# Processing Record 382 of Set 1 | toliary
# Whoops. City not found! But I will keep processing!
# Processing Record 383 of Set 1 | marawi
# Processing Record 384 of Set 1 | nong khai
# Processing Record 385 of Set 1 | esperance
# Processing Record 386 of Set 1 | shache
# Processing Record 387 of Set 1 | ongwediva
# Processing Record 388 of Set 1 | moreno
# Processing Record 389 of Set 1 | sioux lookout
# Processing Record 390 of Set 1 | afgoye
# Whoops. City not found! But I will keep processing!
# Processing Record 391 of Set 1 | sataua
# Whoops. City not found! But I will keep processing!
# Processing Record 392 of Set 1 | vao
# Processing Record 393 of Set 1 | tagusao
# Processing Record 394 of Set 1 | ust-bolsheretsk
# Whoops. City not found! But I will keep processing!
# Processing Record 395 of Set 1 | campos novos
# Processing Record 396 of Set 1 | buala
# Processing Record 397 of Set 1 | naze
# Processing Record 398 of Set 1 | comodoro rivadavia
# Processing Record 399 of Set 1 | havre
# Processing Record 400 of Set 1 | daru
# Processing Record 401 of Set 1 | leh
# Processing Record 402 of Set 1 | campbell river
# Processing Record 403 of Set 1 | galveston
# Processing Record 404 of Set 1 | sijunjung
# Processing Record 405 of Set 1 | metro
# Processing Record 406 of Set 1 | tutoia
# Processing Record 407 of Set 1 | nabire
# Processing Record 408 of Set 1 | faya
# Processing Record 409 of Set 1 | nyimba
# Processing Record 410 of Set 1 | beitbridge
# Processing Record 411 of Set 1 | narsaq
# Processing Record 412 of Set 1 | svetlogorsk
# Processing Record 413 of Set 1 | severo-kurilsk
# Processing Record 414 of Set 1 | pueblo nuevo
# Processing Record 415 of Set 1 | torbay
# Processing Record 416 of Set 1 | grand centre
# Whoops. City not found! But I will keep processing!
# Processing Record 417 of Set 1 | verkhoyansk
# Processing Record 418 of Set 1 | orlik
# Processing Record 419 of Set 1 | anadyr
# Processing Record 420 of Set 1 | pathein
# Processing Record 421 of Set 1 | shelburne
# Processing Record 422 of Set 1 | kinsale
# Processing Record 423 of Set 1 | niort
# Processing Record 424 of Set 1 | nha trang
# Processing Record 425 of Set 1 | antu
# Processing Record 426 of Set 1 | silvania
# Processing Record 427 of Set 1 | sao francisco
# Processing Record 428 of Set 1 | port blair
# Processing Record 429 of Set 1 | satitoa
# Whoops. City not found! But I will keep processing!
# Processing Record 430 of Set 1 | banjar
# Processing Record 431 of Set 1 | corning
# Processing Record 432 of Set 1 | hudson bay
# Processing Record 433 of Set 1 | do gonbadan
# Processing Record 434 of Set 1 | tilichiki
# Processing Record 435 of Set 1 | mandan
# Processing Record 436 of Set 1 | tumannyy
# Whoops. City not found! But I will keep processing!
# Processing Record 437 of Set 1 | port hedland
# Processing Record 438 of Set 1 | warqla
# Whoops. City not found! But I will keep processing!
# Processing Record 439 of Set 1 | nouadhibou
# Processing Record 440 of Set 1 | barentu
# Processing Record 441 of Set 1 | saleaula
# Whoops. City not found! But I will keep processing!
# Processing Record 442 of Set 1 | mount isa
# Processing Record 443 of Set 1 | eirunepe
# Processing Record 444 of Set 1 | san andres
# Processing Record 445 of Set 1 | lesnoy
# Processing Record 446 of Set 1 | tabou
# Processing Record 447 of Set 1 | gizo
# Processing Record 448 of Set 1 | najran
# Processing Record 449 of Set 1 | poya
# Processing Record 450 of Set 1 | abu jubayhah
# Whoops. City not found! But I will keep processing!
# Processing Record 451 of Set 1 | sabang
# Processing Record 452 of Set 1 | bay roberts
# Processing Record 453 of Set 1 | jalu
# Processing Record 454 of Set 1 | general bravo
# Processing Record 455 of Set 1 | wahran
# Whoops. City not found! But I will keep processing!
# Processing Record 456 of Set 1 | elliot lake
# Processing Record 457 of Set 1 | maghama
# Whoops. City not found! But I will keep processing!
# Processing Record 458 of Set 1 | kisesa
# Processing Record 459 of Set 1 | mugur-aksy
# Processing Record 460 of Set 1 | kongsberg
# Processing Record 461 of Set 1 | saint-pierre
# Processing Record 462 of Set 1 | mamou
# Processing Record 463 of Set 1 | clarence town
# Processing Record 464 of Set 1 | darhan
# Processing Record 465 of Set 1 | alexandria
# Processing Record 466 of Set 1 | oktyabrskiy
# Processing Record 467 of Set 1 | vlasenica
# Processing Record 468 of Set 1 | mana
# Processing Record 469 of Set 1 | nelson bay
# Processing Record 470 of Set 1 | mahibadhoo
# Processing Record 471 of Set 1 | lebedinyy
# Processing Record 472 of Set 1 | ippy
# Processing Record 473 of Set 1 | palizada
# Processing Record 474 of Set 1 | karratha
# Processing Record 475 of Set 1 | misratah
# Processing Record 476 of Set 1 | rawah
# Processing Record 477 of Set 1 | sumbe
# Processing Record 478 of Set 1 | puerto lempira
# Processing Record 479 of Set 1 | surab
# Processing Record 480 of Set 1 | provideniya
# Processing Record 481 of Set 1 | los llanos de aridane
# Processing Record 482 of Set 1 | desaguadero
# Processing Record 483 of Set 1 | coihueco
# Processing Record 484 of Set 1 | tahe
# Processing Record 485 of Set 1 | ijaki
# Whoops. City not found! But I will keep processing!
# Processing Record 486 of Set 1 | buenavista
# Processing Record 487 of Set 1 | viligili
# Whoops. City not found! But I will keep processing!
# Processing Record 488 of Set 1 | benguela
# Processing Record 489 of Set 1 | weiser
# Processing Record 490 of Set 1 | mandalgovi
# Processing Record 491 of Set 1 | pitimbu
# Processing Record 492 of Set 1 | viganello
# Processing Record 493 of Set 1 | zabinka
# Whoops. City not found! But I will keep processing!
# Processing Record 494 of Set 1 | mpika
# Processing Record 495 of Set 1 | carupano
# Processing Record 496 of Set 1 | jieshi
# Processing Record 497 of Set 1 | palora
# Processing Record 498 of Set 1 | jurado
# Processing Record 499 of Set 1 | viedma
# Processing Record 500 of Set 1 | touros
# Processing Record 501 of Set 1 | tiznit
# Processing Record 502 of Set 1 | talaya
# Processing Record 503 of Set 1 | havelock
# Processing Record 504 of Set 1 | kismayo
# Processing Record 505 of Set 1 | samalaeulu
# Whoops. City not found! But I will keep processing!
# Processing Record 506 of Set 1 | natal
# Processing Record 507 of Set 1 | mabaruma
# Processing Record 508 of Set 1 | sandwick
# Processing Record 509 of Set 1 | vaitape
# Processing Record 510 of Set 1 | medea
# Processing Record 511 of Set 1 | eydhafushi
# Processing Record 512 of Set 1 | alto araguaia
# Processing Record 513 of Set 1 | nancha
# Processing Record 514 of Set 1 | prabumulih
# Processing Record 515 of Set 1 | souillac
# Processing Record 516 of Set 1 | rabo de peixe
# Processing Record 517 of Set 1 | pringsewu
# Processing Record 518 of Set 1 | saint-paul
# Processing Record 519 of Set 1 | erenhot
# Processing Record 520 of Set 1 | murgab
# Processing Record 521 of Set 1 | emerald
# Processing Record 522 of Set 1 | shingu
# Processing Record 523 of Set 1 | san luis
# Processing Record 524 of Set 1 | mayo
# Processing Record 525 of Set 1 | ewa beach
# Processing Record 526 of Set 1 | yangambi
# Processing Record 527 of Set 1 | bulanash
# Processing Record 528 of Set 1 | deputatskiy
# Processing Record 529 of Set 1 | hauterive
# Processing Record 530 of Set 1 | invermere
# Processing Record 531 of Set 1 | krieglach
# Processing Record 532 of Set 1 | muroto
# Processing Record 533 of Set 1 | isangel
# Processing Record 534 of Set 1 | vardo
# Processing Record 535 of Set 1 | cubatao
# Processing Record 536 of Set 1 | jurm
# Processing Record 537 of Set 1 | mukhen
# Processing Record 538 of Set 1 | baruun-urt
# Processing Record 539 of Set 1 | itarantim
# Processing Record 540 of Set 1 | koumac
# Processing Record 541 of Set 1 | oranjestad
# Processing Record 542 of Set 1 | esil
# Processing Record 543 of Set 1 | guider
# Processing Record 544 of Set 1 | bilma
# Processing Record 545 of Set 1 | khonuu
# Whoops. City not found! But I will keep processing!
# Processing Record 546 of Set 1 | great falls
# Processing Record 547 of Set 1 | jiwani
# Processing Record 548 of Set 1 | baie-saint-paul
# Processing Record 549 of Set 1 | santa maria
# Processing Record 550 of Set 1 | nantucket
# Processing Record 551 of Set 1 | puerto escondido
# Processing Record 552 of Set 1 | kiunga
# Processing Record 553 of Set 1 | rosignol
# Processing Record 554 of Set 1 | ialibu
# Processing Record 555 of Set 1 | kawalu
# Processing Record 556 of Set 1 | pomezia
# Processing Record 557 of Set 1 | suntar
# Processing Record 558 of Set 1 | lukulu
# Processing Record 559 of Set 1 | newark
# Processing Record 560 of Set 1 | takob
# Whoops. City not found! But I will keep processing!
# Processing Record 561 of Set 1 | benque viejo
# Whoops. City not found! But I will keep processing!
# Processing Record 562 of Set 1 | lewistown
# Processing Record 563 of Set 1 | quatre cocos
# Processing Record 564 of Set 1 | ola
# Processing Record 565 of Set 1 | taguing
# Processing Record 566 of Set 1 | lucapa
# Processing Record 567 of Set 1 | shimanovsk
# Processing Record 568 of Set 1 | ahipara
# Processing Record 569 of Set 1 | novyy urgal
# Processing Record 570 of Set 1 | agaro
# Processing Record 571 of Set 1 | aras
# Processing Record 572 of Set 1 | brandon
# Processing Record 573 of Set 1 | kavaratti
# Processing Record 574 of Set 1 | chicama
# Processing Record 575 of Set 1 | davila
# Processing Record 576 of Set 1 | liuzhou
# Processing Record 577 of Set 1 | sao joao da barra
# Processing Record 578 of Set 1 | dapaong
# Processing Record 579 of Set 1 | kegayli
# Whoops. City not found! But I will keep processing!
# Processing Record 580 of Set 1 | itupiranga
# Processing Record 581 of Set 1 | luangwa
# Processing Record 582 of Set 1 | fuyu
# Processing Record 583 of Set 1 | khomutovka
# Processing Record 584 of Set 1 | bemidji
# Processing Record 585 of Set 1 | nicoya
# Processing Record 586 of Set 1 | gangotri
# Whoops. City not found! But I will keep processing!
# Processing Record 587 of Set 1 | towada
# Processing Record 588 of Set 1 | farmington
# Processing Record 589 of Set 1 | boke
# Processing Record 590 of Set 1 | broome
# Processing Record 591 of Set 1 | pundaguitan
# Processing Record 592 of Set 1 | kyshtovka
# Processing Record 593 of Set 1 | sangar
# Processing Record 594 of Set 1 | peniche
# Processing Record 595 of Set 1 | itarema
# Processing Record 596 of Set 1 | abha
# Processing Record 597 of Set 1 | mali
# Processing Record 598 of Set 1 | laguna
# Processing Record 599 of Set 1 | nyaunglebin
# Processing Record 600 of Set 1 | hualmay
# Processing Record 601 of Set 1 | nyuksenitsa
# Processing Record 602 of Set 1 | sawakin
# Processing Record 603 of Set 1 | popondetta
# Processing Record 604 of Set 1 | marzuq
# Processing Record 605 of Set 1 | honiara
# Processing Record 606 of Set 1 | pontianak
# Processing Record 607 of Set 1 | arthur
# Processing Record 608 of Set 1 | msowero
# Processing Record 609 of Set 1 | bento goncalves
# Processing Record 610 of Set 1 | marcona
# Whoops. City not found! But I will keep processing!
# Processing Record 611 of Set 1 | port hardy
# Processing Record 612 of Set 1 | havre-saint-pierre
# Processing Record 613 of Set 1 | mill valley
# Processing Record 614 of Set 1 | pakxan
# Processing Record 615 of Set 1 | russell
# Processing Record 616 of Set 1 | killarney
# Processing Record 617 of Set 1 | asau
# Processing Record 618 of Set 1 | saint-jean-de-maurienne
# Processing Record 619 of Set 1 | ust-ishim
# Processing Record 620 of Set 1 | fernie
# Processing Record 621 of Set 1 | kelvington
# Processing Record 622 of Set 1 | vera cruz
# Processing Record 623 of Set 1 | trairi
# Processing Record 624 of Set 1 | atar
# Processing Record 625 of Set 1 | bardiyah
# Processing Record 626 of Set 1 | salalah
# Processing Record 627 of Set 1 | mindelo
# Processing Record 628 of Set 1 | akureyri
# All done! I managed to get data on 628 cities

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
response
# Out:
# {'coord': {'lon': -18.09, 'lat': 65.68},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 41,
#   'feels_like': 16.88,
#   'temp_min': 41,
#   'temp_max': 41,
#   'pressure': 1015,
#   'humidity': 60},
#  'visibility': 10000,
#  'wind': {'speed': 35.57, 'deg': 190, 'gust': 51.67},
#  'clouds': {'all': 75},
#  'dt': 1584716701,
#  'sys': {'type': 1,
#   'id': 83,
#   'country': 'IS',
#   'sunrise': 1584688275,
#   'sunset': 1584732488},
#  'timezone': 0,
#  'id': 2633274,
#  'name': 'Akureyri',
#  'cod': 200}

# %%
weather = {
    "City": city_name,     
    "Cloudiness":cloudiness,  
    "Country":country,
    "Date": date,        
    "Humidity":humidity,     
    "Lat":lat,           
    "Lng":lng,           
    "Max Temp": max_temp,   
    "Wind Speed": wind_speed}
       
weather_data = pd.DataFrame(weather)
weather_data.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Lat           571
# Lng           571
# Max Temp      571
# Wind Speed    571
# dtype: int64

# %%
weather_data.to_csv(output_data_file)
weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Cidreira          12      BR  1584716635        71 -30.18  -50.21
# 1      Vaini          75      TO  1584716635        88 -21.20 -175.20
# 2  Upernavik           0      GL  1584716635        93  72.79  -56.15
# 3     Rusape          93      ZW  1584716635        58 -18.53   32.13
# 4       Kaeo           2      NZ  1584716635        93 -35.10  173.78
#
#    Max Temp  Wind Speed
# 0     71.15       16.42
# 1     77.00       11.41
# 2    -13.43        8.61
# 3     73.69        8.48
# 4     60.01        8.34

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
from datetime import date
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2020-03-20

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], 
            color="lightblue",edgecolors = "k", s=40)
plt.title(f"Latitude vs. Max Temperature as of {today}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], 
            color="lightblue",edgecolors = "k", s=40)
plt.title(f"Latitude vs. Humidity as of {today}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], 
            color="lightblue",edgecolors = "k", s=40)
plt.title(f"Latitude vs. Cloudiness as of {today}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], 
            color="lightblue",edgecolors = "k", s=40)
plt.title(f"Latitude vs. Wind Speed as of {today}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
